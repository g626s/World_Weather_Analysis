# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0         Hobart      AU -42.8794  147.3294     59.25        76
# 1        1  Mount Gambier      AU -37.8333  140.7667     60.94        69
# 2        2         Cusset      FR  46.1300    3.4596     63.52        76
# 3        3    New Norfolk      AU -42.7826  147.0587     56.64        80
# 4        4         Maridi      SS   4.9158   29.4742     71.89        89
#
#    Cloudiness  Wind Speed Current Description
# 0          75        5.75       broken clouds
# 1          66        7.99       broken clouds
# 2           9        2.19           clear sky
# 3          47        1.05    scattered clouds
# 4          68        2.64       broken clouds

# %% [markdown]
# Confirm the data types for the data columns are integers or floating-point decimal numbers.

# %%
# Get the data types.
city_data_df.dtypes
# Out:
# City_ID                  int64
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# Create a Maximum Temperature Heatmap

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Create a maximum temp heatmap.

# Heatmap of temperature

# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]

# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, 
                                 weights=[max(temp, 0) for temp in max_temp], 
                                 dissipating=False, 
                                 max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Create a Percent Humidity Heatmap

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Create a Percent Cloudiness Heatmap

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Create a Wind Speed Heatmap

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Get Vacation Criteria

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 90
# What is the maximum temperature you would like for your trip? 100

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#      City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 105      105      Padampur      IN  29.6833   73.6167     94.62        50
# 109      109  Saint George      US  37.1041 -113.5841     90.25        34
# 129      129        Murgab      TM  37.4966   61.9714     91.27        31
# 132      132         Darab      IR  28.7519   54.5444     93.33        28
# 228      228         Nizwa      OM  22.9333   57.5333     91.26        53
# 258      258         Tanda      IN  26.5500   82.6500     92.93        53
# 280      280       Jiuquan      CN  39.7432   98.5174     92.48        12
# 289      289       Amuntai      ID  -2.4177  115.2494     93.88        42
# 313      313     Sherghati      IN  24.5667   84.7833     91.02        45
# 333      333          Taft      IR  31.7471   54.2088     94.95        10
#
#      Cloudiness  Wind Speed Current Description
# 105          98       15.93     overcast clouds
# 109           0        8.05           clear sky
# 129           0       11.50           clear sky
# 132          16        4.81          few clouds
# 228          42        4.54    scattered clouds
# 258          97       19.04     overcast clouds
# 280           1        5.66           clear sky
# 289          35        1.86    scattered clouds
# 313          97       10.29     overcast clouds
# 333           0        9.22           clear sky

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                32
# City                   32
# Country                32
# Lat                    32
# Lng                    32
# Max Temp               32
# Humidity               32
# Cloudiness             32
# Wind Speed             32
# Current Description    32
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp Current Description      Lat       Lng  \
# 105      Padampur      IN     94.62     overcast clouds  29.6833   73.6167
# 109  Saint George      US     90.25           clear sky  37.1041 -113.5841
# 129        Murgab      TM     91.27           clear sky  37.4966   61.9714
# 132         Darab      IR     93.33          few clouds  28.7519   54.5444
# 228         Nizwa      OM     91.26    scattered clouds  22.9333   57.5333
# 258         Tanda      IN     92.93     overcast clouds  26.5500   82.6500
# 280       Jiuquan      CN     92.48           clear sky  39.7432   98.5174
# 289       Amuntai      ID     93.88    scattered clouds  -2.4177  115.2494
# 313     Sherghati      IN     91.02     overcast clouds  24.5667   84.7833
# 333          Taft      IR     94.95           clear sky  31.7471   54.2088
#
#     Hotel Name
# 105
# 109
# 129
# 132
# 228
# 258
# 280
# 289
# 313
# 333

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df["Hotel Name"]!=""
# Out:
# 105     True
# 109     True
# 129     True
# 132     True
# 228     True
# 258     True
# 280     True
# 289     True
# 313     True
# 333     True
# 361    False
# 365     True
# 368     True
# 396     True
# 435     True
# 438     True
# 458     True
# 470     True
# 476     True
# 479     True
# 485     True
# 529    False
# 545     True
# 576     True
# 580     True
# 615    False
# 621    False
# 637     True
# 638     True
# 680     True
# 698    False
# 717     True
# Name: Hotel Name, dtype: bool

# %%
hotel_df.count()
# Out:
# City                   32
# Country                32
# Max Temp               32
# Current Description    32
# Lat                    32
# Lng                    32
# Hotel Name             32
# dtype: int64

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df["Hotel Name"]!=""]
clean_hotel_df
# Out:
#                   City Country  Max Temp Current Description      Lat  \
# 105           Padampur      IN     94.62     overcast clouds  29.6833
# 109       Saint George      US     90.25           clear sky  37.1041
# 129             Murgab      TM     91.27           clear sky  37.4966
# 132              Darab      IR     93.33          few clouds  28.7519
# 228              Nizwa      OM     91.26    scattered clouds  22.9333
# 258              Tanda      IN     92.93     overcast clouds  26.5500
# 280            Jiuquan      CN     92.48           clear sky  39.7432
# 289            Amuntai      ID     93.88    scattered clouds  -2.4177
# 313          Sherghati      IN     91.02     overcast clouds  24.5667
# 333               Taft      IR     94.95           clear sky  31.7471
# 365           Victoria      HK     96.85           clear sky  22.2855
# 368                Sur      OM     92.46       broken clouds  22.5667
# 396              Dubai      AE     98.85    scattered clouds  25.2582
# 435               Hami      CN    100.00           clear sky  42.8000
# 438          Yangjiang      CN     91.98           clear sky  21.8500
# 458             Haimen      CN     98.49           clear sky  23.1935
# 470          Nishihara      JP     91.06          few clouds  26.1842
# 476            Shihezi      CN     94.42    scattered clouds  44.3000
# 479             Hasaki      JP     91.80       broken clouds  35.7333
# 485             Jinhua      CN     98.94           clear sky  29.1078
# 545         Santa Rosa      PH     95.09     overcast clouds  14.3122
# 576  Fortuna Foothills      US     91.22           clear sky  32.6578
# 580             Bosaso      SO     93.09    scattered clouds  11.2842
# 637            Zhifang      CN     92.10           clear sky  30.3500
# 638              Macau      MO     96.60          few clouds  22.2006
# 680             Nushki      PK     93.83       broken clouds  29.5542
# 717            Encheng      CN     96.96           clear sky  22.1839
#
#           Lng                                   Hotel Name
# 105   73.6167                             Sidhu wali dhani
# 109 -113.5841                  Best Western Plus Abbey Inn
# 129   61.9714                                Wepa Nurlyýew
# 132   54.5444                        Naghshe shapoor Hotel
# 228   57.5333                            Orient Apartments
# 258   82.6500                            MUMTAZ GANJ TANDA
# 280   98.5174                                Jiuquan Hotel
# 289  115.2494                                 Hotel Balqis
# 313   84.7833                                   Mamu Hotal
# 333   54.2088                              عمارت ساعتی تفت
# 365  114.1577                                 Mini Central
# 368   59.5289                              Sur Plaza Hotel
# 396   55.3047        Radisson Blu Hotel, Dubai Deira Creek
# 435   93.4500                             Laoyutang Resort
# 438  111.9667                HUALUXE Yangjiang City Center
# 458  116.6142               Shantou Chaoyang Donghui Hotel
# 470  127.7558                            Minshuku Agaihama
# 476   86.0333  Home Inn Shihezi Dongwu Road Century Square
# 479  140.8333                        Inubosaki Kanko Hotel
# 485  119.6547                                   Yayi Hotel
# 545  121.1114                   Erlyn’s Sta Rosa City Home
# 576 -114.4119                       Fortuna De Oro RV Park
# 580   49.1816                                Red Sea Hotel
# 637  114.3167         Echarm Hotel Jiangxia Zhongbai Plaza
# 638  113.5461                          Grand Emperor Hotel
# 680   66.0215                                  Shams hotel
# 717  112.3026                                Pinghu Hostel

# %%
# 8a. Create the output File (CSV)
output_data_file = "Vacation_Search/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} </dd>

</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
city_description = hotel_df["Current Description"]

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [20], in <cell line: 9>()
#       6 fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#       7 heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
#       8              max_intensity=300, point_radius=4)
# ----> 9 marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#      10 fig.add_layer(heat_layer)
#      11 fig.add_layer(marker_layer)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gmaps/marker.py:553, in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     485 @doc_subst(_doc_snippets)
#     486 def marker_layer(
#     487         locations, hover_text='', label='',
#     488         info_box_content=None, display_info_box=None):
#     489     """
#     490     Marker layer
#     491
#    (...)
#     551         A :class:`gmaps.Markers` instance.
#     552     """
# --> 553     marker_options = _marker_layer_options(
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
#     556     return Markers(markers=markers)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gmaps/marker.py:320, in _marker_layer_options(locations, hover_text, label, info_box_content, display_info_box)
#     312     info_box_content = [info_box_content] * number_markers
#     314 marker_options = {
#     315     'location': locations_to_list(locations),
#     316     'hover_text': hover_text,
#     317     'label': label
#     318 }
# --> 320 info_box_options = _info_box_option_lists(
#     321     number_markers, info_box_content, display_info_box)
#     323 marker_options.update(info_box_options)
#     325 return merge_option_dicts(marker_options)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gmaps/marker.py:254, in _info_box_option_lists(number_markers, info_box_content, display_info_box)
#     252 for imarker in range(number_markers):
#     253     if display_info_box[imarker] is None:
# --> 254         is_content_empty = (info_box_content[imarker] is None)
#     255         if is_content_empty:
#     256             display_info_box[imarker] = False
#
# IndexError: list index out of range
